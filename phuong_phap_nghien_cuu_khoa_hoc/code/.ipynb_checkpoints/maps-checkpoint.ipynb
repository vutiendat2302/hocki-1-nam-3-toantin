# %%
# Cài thư viện
import osmnx as ox #open street map: mô hình hóa và trực quan hóa mạng lưới giao thông
import requests # gọi api
import pandas as pd # Xử lý phân tích và làm sạch dữ liệu
import numpy as np # tính toán
import time # thời gian
from datetime import datetime, timedelta
import networkx as nx # thư viện dùng để tạo, nghiên cứu cấu trúc của grap
import folium
CENTER_POINT = (21.0025, 105.8037) 
# Bán kính 3km (đủ bao trùm Vành đai 3 và các đường lân cận như Nguyễn Trãi, Khuất Duy Tiến)
DISTANCE_M = 3000
# Bỏ qua đường dân sinh, đường nội bộ chỉ lấy cao tốc, quốc lộ, đường trục, đườn cấp 1, cấp 2
cf = '["highway"~"motorway|trunk|primary|secondary"]'
# Cấu hình thời gian (7 ngày, 5 phút/lần)
DAYS = 1
FREQ_MIN = 5
TOTAL_STEPS = (24 * 60 // FREQ_MIN) * DAYS # 2016 bước thời gian
MAX_EDGES_TO_SAMPLE = 1000 # giới hạn 1000 cạnh
print(f"🚀 Đang khởi tạo quy trình sinh dữ liệu cho {DAYS} ngày ({TOTAL_STEPS} bước)...")
G = ox.graph_from_point(
    CENTER_POINT, 
    dist=DISTANCE_M, 
    network_type="drive",
    custom_filter=cf
) # lấy grap
# Lấy danh sách các Nút (Nodes) - Đây chính là N trong mô hình T-GCN
nodes_gdf = ox.graph_to_gdfs(G, edges=False, nodes=True)
node_ids = nodes_gdf.index.tolist()
num_nodes = len(node_ids)

# Tạo Ma trận Kề (Adjacency Matrix)
adj_matrix = nx.adjacency_matrix(G).todense()

print(f"✅ Đã tạo Graph thành công!")
print(f"   - Số lượng Nút (Nodes/Sensors): {num_nodes}")
print(f"   - Kích thước Ma trận kề: {adj_matrix.shape}")
# Out:
# 🚀 Đang khởi tạo quy trình sinh dữ liệu cho 1 ngày (288 bước)...
# ✅ Đã tạo Graph thành công!
#    - Số lượng Nút (Nodes/Sensors): 624
#    - Kích thước Ma trận kề: (624, 624)

# %%
import requests
import pandas as pd
import time
import os
from datetime import datetime, timedelta
# from tqdm import tqdm # Thanh tiến trình

# ==========================================
# 1. CẤU HÌNH CHẠY 3 TIẾNG
# ==========================================
MAPS_API_KEY = "AIzaSyDlHb6dRekvMlMOkWPfWoUPXm_gFKU10Yc"

# Thời gian chạy (Giờ)
HOURS_TO_RUN = 10
INTERVAL_MINUTES = 5

# Tính thời điểm dừng
START_TIME = datetime.now()
END_TIME = START_TIME + timedelta(hours=HOURS_TO_RUN)

# Tên file lưu
OUTPUT_FILE = f"hanoi_traffic_FULL_SCAN_{START_TIME.strftime('%Y%m%d_%H%M')}.csv"

# ==========================================
# 2. CHUẨN BỊ DANH SÁCH TOÀN BỘ CẠNH
# ==========================================
print("📊 Đang tải toàn bộ danh sách cạnh từ Graph...")

# Lấy tất cả cạnh (Full Scan)
edges_gdf = ox.graph_to_gdfs(G, nodes=False, edges=True).reset_index()
total_edges = len(edges_gdf)



print(f"✅ Đã tìm thấy {total_edges} đoạn đường.")
print(f"⏳ Sẽ chạy trong {HOURS_TO_RUN} tiếng (Dự kiến kết thúc: {END_TIME.strftime('%H:%M:%S')})")
print(f"📂 Dữ liệu sẽ lưu vào: {OUTPUT_FILE}")

# Lấy tọa độ nút để tra cứu
nodes_lookup = ox.graph_to_gdfs(G, edges=False, nodes=True)

# ==========================================
# 3. HÀM GỌI API (Gọn nhẹ)
# ==========================================
def fetch_full_batch(edge_list, nodes_df):
    batch_results = []
    
    # Dùng tqdm để hiện thanh chạy cho đỡ sốt ruột
    print(f"   ⚡ Đang quét {len(edge_list)} cạnh...")
    
    for index, row in edge_list.iterrows():
        u, v = row['u'], row['v']
        try:
            origin = f"{nodes_df.loc[u].y},{nodes_df.loc[u].x}"
            destination = f"{nodes_df.loc[v].y},{nodes_df.loc[v].x}"
            
            url = "https://maps.googleapis.com/maps/api/directions/json"
            params = {
                "origin": origin, "destination": destination,
                "mode": "driving", "departure_time": "now", "key": MAPS_API_KEY
            }
            
            # Timeout ngắn để lướt qua nhanh nếu mạng lag
            resp = requests.get(url, params=params, timeout=2) 
            data = resp.json()
            
            if data['status'] == 'OK':
                leg = data['routes'][0]['legs'][0]
                dist = leg['distance']['value']
                dur = leg['duration_in_traffic']['value']
                
                # Tính tốc độ
                speed = (dist / dur) * 3.6 if dur > 0 else 0
                
                batch_results.append({
                    'timestamp': datetime.now(),
                    'edge_id': f"{u}_{v}",
                    'speed_kmh': round(speed, 2),
                    'duration_s': dur,
                    'distance_m': dist
                })
                
            # Ngủ cực ngắn để giảm tải CPU và tránh spam quá gắt
            time.sleep(0.01)
            
        except Exception:
            continue 
            
    return batch_results

# ==========================================
# 4. VÒNG LẶP CHÍNH
# ==========================================
loop_count = 0

while datetime.now() < END_TIME:
    loop_start = datetime.now()
    loop_count += 1
    
    print(f"\n🔄 Vòng {loop_count} | Bắt đầu: {loop_start.strftime('%H:%M:%S')}")
    
    # 1. Gọi API cho toàn bộ Graph
    new_data = fetch_full_batch(edges_gdf, nodes_lookup)
    
    # 2. Lưu file ngay lập tức
    if new_data:
        df_new = pd.DataFrame(new_data)
        header_mode = not os.path.exists(OUTPUT_FILE)
        df_new.to_csv(OUTPUT_FILE, mode='a', header=header_mode, index=False)
        print(f"   💾 Đã lưu {len(new_data)} dòng dữ liệu.")
    
    # 3. Ngủ bù giờ
    elapsed = (datetime.now() - loop_start).total_seconds()
    sleep_time = (INTERVAL_MINUTES * 60) - elapsed
    
    if sleep_time > 0:
        print(f"   💤 Ngủ {int(sleep_time)} giây chờ lượt tiếp theo...")
        time.sleep(sleep_time)
    else:
        print("   ⚠️ Quét full lâu hơn 5 phút, chạy tiếp ngay!")

print("\n🎉 HOÀN TẤT 3 TIẾNG THU THẬP!")
# Out:
# 📊 Đang tải toàn bộ danh sách cạnh từ Graph...
# ✅ Đã tìm thấy 1061 đoạn đường.
# ⏳ Sẽ chạy trong 3 tiếng (Dự kiến kết thúc: 15:11:01)
# 📂 Dữ liệu sẽ lưu vào: hanoi_traffic_FULL_SCAN_20251127_1211.csv
#
# 🔄 Vòng 1 | Bắt đầu: 12:11:01
#    ⚡ Đang quét 1061 cạnh...
# [{'timestamp': datetime.datetime(2025, 11, 27, 12, 11, 1, 349943), 'edge_id': '81805393_11950483412', 'speed_kmh': 4.5, 'duration_s': 12, 'distance_m': 15}, {'timestamp': datetime.datetime(2025, 11, 27, 12,
, {'timestamp': datetime.datetime(2025, 11, 27, 12, 16, 4, 237497), 'edge_id': '98041849_5718871870', 'speed_kmh': 18.9, 'duration_s': 4, 'distance_m': 21}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 16, 4, 385989), 'edge_id': '98041849_733429120', 'speed_kmh': 5.57, 'duration_s': 42, 'distance_m': 65}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 16, 4, 541448), 'edge_id': '98041851_98041254', 'speed_kmh': 22.57, 'duration_s': 167, 'distance_m': 1047}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 16, 4, 726472), 'edge_id': '98041851_2084132002', 'speed_kmh': 27.36, 'duration_s': 5, 'distance_m': 38}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 16, 4, 885152), 'edge_id': '98042270_309816682', 'speed_kmh': 16.6, 'duration_s': 134, 'distance_m': 618}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 16, 5, 96813), 'edge_id': '98042270_6677300866', 'speed_kmh': 18.37, 'duration_s': 58, 'distance_m': 296}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 16, 5, 310378), 'edge_id': '106078638_6587651 ...
#    💾 Đã lưu 1011 dòng dữ liệu.
#    💤 Ngủ 137 giây chờ lượt tiếp theo...
#
# 🔄 Vòng 3 | Bắt đầu: 12:21:01
#    ⚡ Đang quét 1061 cạnh...
# [{'timestamp': datetime.datetime(2025, 11, 27, 12, 21, 1, 283946), 'edge_id': '81805393_11950483412', 'speed_kmh': 4.15, 'duration_s': 13, 'distance_m': 15}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 21, 1, 512143), 'edge_id': '81805393_1884765798', 'speed_kmh': 14.08, 'duration_s': 237, 'distance_m': 927}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 21, 1, 719696), 'edge_id': '81806535_1497544749', 'speed_kmh': 15.2, 'duration_s': 9, 'distance_m': 38}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 21, 1, 867583), 'edge_id': '81806535_5707161153', 'speed_kmh': 9.63, 'duration_s': 108, 'distance_m': 289}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 21, 2, 15843), 'edge_id': '98026475_6677338241', 'speed_kmh': 18.57, 'duration_s': 119, 'distance_m': 614}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 21, 2, 140014), 'edge_id': '98027697_4599745018', 'speed_kmh': 7.44, 'duration_s': 15, 'distance_m': 31}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 21, 2, 379635), 'edge_id': '98027697_7985603138', 'speed_kmh': 18.51, 'duration_s': 7, 'distance_m': 36}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 21, 2, 533089), 'edge_id': '98027697_10130533953', 'speed_kmh': 13.88, 'duration_s': 187, 'distance_m': 721}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 21, 2, 659423), 'edge_id': '98031401_6661055810', 'speed_kmh': 0.0, 'duration_s': 13, 'distance_m': 0}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 21, 2, 789362), 'edge_id': '98031401_8823455179', 'speed_kmh': 11.56, 'duration_s': 85, 'distance_m': 273}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 21, 2, 986801), 'edge_id': '98035472_309816683', 'speed_kmh': 13.68, 'duration_s': 190, 'distance_m': 722}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 21, 3, 118315), 'edge_id': '98035472_12816414547', 'speed_kmh': 13.3, 'duration_s': 243, 'distance_m': 898}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 21, 3, 271423), 'edge_id': '98035472_5718916293', 'speed_kmh': 16.4, 'duration_s': 9, 'distance_m': 41}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 21, 3, 480985), 'edge_id': '98041254_420456615', 'speed_kmh': 11.7, 'duration_s': 4, 'distance_m': 13}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 21, 3, 691720), 'edge_id': '98041254_420522002', 'speed_kmh': 24.48, 'duration_s': 5, 'distance_m': 34}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 21, 3, 824917), 'edge_id': '98041257_98041849', 'speed_kmh': 9.49, 'duration_s': 11, 'distance_m': 29}, {'timestamp': datetime.datetime(2025, 11, 27, 12,
, {'timestamp': datetime.datetime(2025, 11, 27, 12, 51, 4, 578489), 'edge_id': '98041849_5718871870', 'speed_kmh': 18.9, 'duration_s': 4, 'distance_m': 21}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 51, 4, 713205), 'edge_id': '98041849_733429120', 'speed_kmh': 9.75, 'duration_s': 24, 'distance_m': 65}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 51, 4, 914263), 'edge_id': '98041851_98041254', 'speed_kmh': 24.01, 'duration_s': 157, 'distance_m': 1047}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 51, 5, 110690), 'edge_id': '98041851_2084132002', 'speed_kmh': 34.2, 'duration_s': 4, 'distance_m': 38}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 51, 5, 394252), 'edge_id': '98042270_309816682', 'speed_kmh': 18.7, 'duration_s': 119, 'distance_m': 618}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 51, 5, 599358), 'edge_id': '98042270_6677300866', 'speed_kmh': 19.37, 'duration_s': 55, 'distance_m': 296}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 51, 5, 740063), 'edge_id': '106078638_6 ...
#    💾 Đã lưu 1061 dòng dữ liệu.
#    💤 Ngủ 119 giây chờ lượt tiếp theo...
#
# 🔄 Vòng 10 | Bắt đầu: 12:56:01
#    ⚡ Đang quét 1061 cạnh...
# [{'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 1, 266168), 'edge_id': '81805393_11950483412', 'speed_kmh': 4.15, 'duration_s': 13, 'distance_m': 15}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 1, 429384), 'edge_id': '81805393_1884765798', 'speed_kmh': 15.03, 'duration_s': 222, 'distance_m': 927}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 1, 564658), 'edge_id': '81806535_1497544749', 'speed_kmh': 13.68, 'duration_s': 10, 'distance_m': 38}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 1, 696810), 'edge_id': '81806535_5707161153', 'speed_kmh': 9.05, 'duration_s': 115, 'distance_m': 289}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 1, 845127), 'edge_id': '98026475_6677338241', 'speed_kmh': 19.56, 'duration_s': 113, 'distance_m': 614}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 1, 983707), 'edge_id': '98027697_4599745018', 'speed_kmh': 10.15, 'duration_s': 11, 'distance_m': 31}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 2, 124453), 'edge_id': '98027697_7985603138', 'speed_kmh': 21.6, 'duration_s': 6, 'distance_m': 36}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 2, 272494), 'edge_id': '98027697_10130533953', 'speed_kmh': 16.85, 'duration_s': 154, 'distance_m': 721}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 2, 408480), 'edge_id': '98031401_6661055810', 'speed_kmh': 0.0, 'duration_s': 13, 'distance_m': 0}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 2, 572103), 'edge_id': '98031401_8823455179', 'speed_kmh': 11.17, 'duration_s': 88, 'distance_m': 273}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 2, 702296), 'edge_id': '98035472_309816683', 'speed_kmh': 16.56, 'duration_s': 157, 'distance_m': 722}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 2, 841241), 'edge_id': '98035472_12816414547', 'speed_kmh': 15.25, 'duration_s': 212, 'distance_m': 898}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 3, 7312), 'edge_id': '98035472_5718916293', 'speed_kmh': 16.4, 'duration_s': 9, 'distance_m': 41}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 3, 163928), 'edge_id': '98041254_420456615', 'speed_kmh': 9.36, 'duration_s': 5, 'distance_m': 13}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 3, 311608), 'edge_id': '98041254_420522002', 'speed_kmh': 24.48, 'duration_s': 5, 'distance_m': 34}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 3, 459935), 'edge_id': '98041257_98041849', 'speed_kmh': 10.44, 'duration_s': 10, 'distance_m': 29}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 3, 642804), 'edge_id': '98041257_5710673974', 'speed_kmh': 19.8, 'duration_s': 4, 'distance_m': 22}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 3, 786787), 'edge_id': '98041257_5710673979', 'speed_kmh': 32.4, 'duration_s': 3, 'distance_m': 27}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 3, 949096), 'edge_id': '98041849_98041257', 'speed_kmh': 10.44, 'duration_s': 10, 'distance_m': 29}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 4, 113139), 'edge_id': '98041849_5718871870', 'speed_kmh': 18.9, 'duration_s': 4, 'distance_m': 21}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 4, 239437), 'edge_id': '98041849_733429120', 'speed_kmh': 11.14, 'duration_s': 21, 'distance_m': 65}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 4, 394244), 'edge_id': '98041851_98041254', 'speed_kmh': 23.41, 'duration_s': 161, 'distance_m': 1047}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 4, 549757), 'edge_id': '98041851_2084132002', 'speed_kmh': 34.2, 'duration_s': 4, 'distance_m': 38}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 4, 684710), 'edge_id': '98042270_309816682', 'speed_kmh': 19.52, 'duration_s': 114, 'distance_m': 618}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 4, 810519), 'edge_id': '98042270_6677300866', 'speed_kmh': 19.73, 'duration_s': 54, 'distance_m': 296}, {'timestamp': datetime.datetime(2025, 11, 27, 12, 56, 4, 962652), 'edge_id': '1060786 ...
#    💾 Đã lưu 1061 dòng dữ liệu.
#    💤 Ngủ 130 giây chờ lượt tiếp theo...
#
# 🔄 Vòng 11 | Bắt đầu: 13:01:01
#    ⚡ Đang quét 1061 cạnh...
# [{'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 1, 288348), 'edge_id': '81805393_11950483412', 'speed_kmh': 4.5, 'duration_s': 12, 'distance_m': 15}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 1, 453012), 'edge_id': '81805393_1884765798', 'speed_kmh': 15.52, 'duration_s': 215, 'distance_m': 927}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 1, 651013), 'edge_id': '81806535_1497544749', 'speed_kmh': 8.05, 'duration_s': 17, 'distance_m': 38}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 1, 810452), 'edge_id': '81806535_5707161153', 'speed_kmh': 9.21, 'duration_s': 113, 'distance_m': 289}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 1, 970711), 'edge_id': '98026475_6677338241', 'speed_kmh': 19.56, 'duration_s': 113, 'distance_m': 614}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 2, 94054), 'edge_id': '98027697_4599745018', 'speed_kmh': 10.15, 'duration_s': 11, 'distance_m': 31}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 2, 240210), 'edge_id': '98027697_7985603138', 'speed_kmh': 21.6, 'duration_s': 6, 'distance_m': 36}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 2, 451459), 'edge_id': '98027697_10130533953', 'speed_kmh': 16.96, 'duration_s': 153, 'distance_m': 721}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 2, 644725), 'edge_id': '98031401_6661055810', 'speed_kmh': 0.0, 'duration_s': 16, 'distance_m': 0}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 2, 862934), 'edge_id': '98031401_8823455179', 'speed_kmh': 11.84, 'duration_s': 83, 'distance_m': 273}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 3, 35160), 'edge_id': '98035472_309816683', 'speed_kmh': 16.88, 'duration_s': 154, 'distance_m': 722}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 3, 182182), 'edge_id': '98035472_12816414547', 'speed_kmh': 15.47, 'duration_s': 209, 'distance_m': 898}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 3, 315292), 'edge_id': '98035472_5718916293', 'speed_kmh': 18.45, 'duration_s': 8, 'distance_m': 41}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 3, 524240), 'edge_id': '98041254_420456615', 'speed_kmh': 9.36, 'duration_s': 5, 'distance_m': 13}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 3, 665711), 'edge_id': '98041254_420522002', 'speed_kmh': 24.48, 'duration_s': 5, 'distance_m': 34}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 3, 809936), 'edge_id': '98041257_98041849', 'speed_kmh': 10.44, 'duration_s': 10, 'distance_m': 29}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 3, 950414), 'edge_id': '98041257_5710673974', 'speed_kmh': 19.8, 'duration_s': 4, 'distance_m': 22}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 4, 125768), 'edge_id': '98041257_5710673979', 'speed_kmh': 32.4, 'duration_s': 3, 'distance_m': 27}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 4, 263822), 'edge_id': '98041849_98041257', 'speed_kmh': 7.46, 'duration_s': 14, 'distance_m': 29}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 4, 429292), 'edge_id': '98041849_5718871870', 'speed_kmh': 18.9, 'duration_s': 4, 'distance_m': 21}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 4, 580931), 'edge_id': '98041849_733429120', 'speed_kmh': 12.32, 'duration_s': 19, 'distance_m': 65}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 4, 728261), 'edge_id': '98041851_98041254', 'speed_kmh': 23.12, 'duration_s': 163, 'distance_m': 1047}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 4, 875754), 'edge_id': '98041851_2084132002', 'speed_kmh': 34.2, 'duration_s': 4, 'distance_m': 38}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 5, 48764), 'edge_id': '98042270_309816682', 'speed_kmh': 18.7, 'duration_s': 119, 'distance_m': 618}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 5, 244271), 'edge_id': '98042270_6677300866', 'speed_kmh': 19.03, 'duration_s': 56, 'distance_m': 296}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 1, 5, 402707), 'edge_id': '106078638_6587651051', 'speed_kmh': 3 ...
#    💾 Đã lưu 1061 dòng dữ liệu.
#    💤 Ngủ 119 giây chờ lượt tiếp theo...
#
# 🔄 Vòng 12 | Bắt đầu: 13:06:01
#    ⚡ Đang quét 1061 cạnh...
# [{'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 1, 350041), 'edge_id': '81805393_11950483412', 'speed_kmh': 4.15, 'duration_s': 13, 'distance_m': 15}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 1, 533760), 'edge_id': '81805393_1884765798', 'speed_kmh': 15.89, 'duration_s': 210, 'distance_m': 927}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 1, 670702), 'edge_id': '81806535_1497544749', 'speed_kmh': 13.68, 'duration_s': 10, 'distance_m': 38}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 1, 801465), 'edge_id': '81806535_5707161153', 'speed_kmh': 9.13, 'duration_s': 114, 'distance_m': 289}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 1, 941156), 'edge_id': '98026475_6677338241', 'speed_kmh': 18.42, 'duration_s': 120, 'distance_m': 614}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 2, 138116), 'edge_id': '98027697_4599745018', 'speed_kmh': 11.16, 'duration_s': 10, 'distance_m': 31}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 2, 379484), 'edge_id': '98027697_7985603138', 'speed_kmh': 21.6, 'duration_s': 6, 'distance_m': 36}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 2, 540083), 'edge_id': '98027697_10130533953', 'speed_kmh': 16.85, 'duration_s': 154, 'distance_m': 721}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 2, 734789), 'edge_id': '98031401_6661055810', 'speed_kmh': 0.0, 'duration_s': 12, 'distance_m': 0}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 2, 897629), 'edge_id': '98031401_8823455179', 'speed_kmh': 10.03, 'duration_s': 98, 'distance_m': 273}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 3, 46443), 'edge_id': '98035472_309816683', 'speed_kmh': 16.35, 'duration_s': 159, 'distance_m': 722}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 3, 187741), 'edge_id': '98035472_12816414547', 'speed_kmh': 15.11, 'duration_s': 214, 'distance_m': 898}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 3, 356819), 'edge_id': '98035472_5718916293', 'speed_kmh': 18.45, 'duration_s': 8, 'distance_m': 41}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 3, 549269), 'edge_id': '98041254_420456615', 'speed_kmh': 9.36, 'duration_s': 5, 'distance_m': 13}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 3, 684393), 'edge_id': '98041254_420522002', 'speed_kmh': 24.48, 'duration_s': 5, 'distance_m': 34}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 3, 951330), 'edge_id': '98041257_98041849', 'speed_kmh': 10.44, 'duration_s': 10, 'distance_m': 29}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 4, 161836), 'edge_id': '98041257_5710673974', 'speed_kmh': 19.8, 'duration_s': 4, 'distance_m': 22}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 4, 398225), 'edge_id': '98041257_5710673979', 'speed_kmh': 32.4, 'duration_s': 3, 'distance_m': 27}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 4, 557682), 'edge_id': '98041849_98041257', 'speed_kmh': 9.49, 'duration_s': 11, 'distance_m': 29}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 4, 771584), 'edge_id': '98041849_5718871870', 'speed_kmh': 15.12, 'duration_s': 5, 'distance_m': 21}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 4, 954684), 'edge_id': '98041849_733429120', 'speed_kmh': 8.67, 'duration_s': 27, 'distance_m': 65}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 5, 107065), 'edge_id': '98041851_98041254', 'speed_kmh': 22.3, 'duration_s': 169, 'distance_m': 1047}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 5, 237242), 'edge_id': '98041851_2084132002', 'speed_kmh': 34.2, 'duration_s': 4, 'distance_m': 38}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 5, 428462), 'edge_id': '98042270_309816682', 'speed_kmh': 17.8, 'duration_s': 125, 'distance_m': 618}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 5, 626715), 'edge_id': '98042270_6677300866', 'speed_kmh': 19.37, 'duration_s': 55, 'distance_m': 296}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 6, 5, 833641), 'edge_id': '106078638_6587651051', 'speed_kmh' ...
#    💾 Đã lưu 1061 dòng dữ liệu.
#    💤 Ngủ 108 giây chờ lượt tiếp theo...
#
# 🔄 Vòng 13 | Bắt đầu: 13:11:01
#    ⚡ Đang quét 1061 cạnh...
# [{'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 1, 293690), 'edge_id': '81805393_11950483412', 'speed_kmh': 4.91, 'duration_s': 11, 'distance_m': 15}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 1, 451070), 'edge_id': '81805393_1884765798', 'speed_kmh': 17.03, 'duration_s': 196, 'distance_m': 927}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 1, 589235), 'edge_id': '81806535_1497544749', 'speed_kmh': 13.68, 'duration_s': 10, 'distance_m': 38}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 1, 715944), 'edge_id': '81806535_5707161153', 'speed_kmh': 9.05, 'duration_s': 115, 'distance_m': 289}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 1, 883403), 'edge_id': '98026475_6677338241', 'speed_kmh': 18.73, 'duration_s': 118, 'distance_m': 614}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 2, 24302), 'edge_id': '98027697_4599745018', 'speed_kmh': 9.3, 'duration_s': 12, 'distance_m': 31}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 2, 156880), 'edge_id': '98027697_7985603138', 'speed_kmh': 21.6, 'duration_s': 6, 'distance_m': 36}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 2, 316111), 'edge_id': '98027697_10130533953', 'speed_kmh': 16.12, 'duration_s': 161, 'distance_m': 721}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 2, 446603), 'edge_id': '98031401_6661055810', 'speed_kmh': 0.0, 'duration_s': 10, 'distance_m': 0}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 2, 598687), 'edge_id': '98031401_8823455179', 'speed_kmh': 10.24, 'duration_s': 96, 'distance_m': 273}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 2, 831266), 'edge_id': '98035472_309816683', 'speed_kmh': 16.45, 'duration_s': 158, 'distance_m': 722}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 2, 988877), 'edge_id': '98035472_12816414547', 'speed_kmh': 15.47, 'duration_s': 209, 'distance_m': 898}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 3, 131617), 'edge_id': '98035472_5718916293', 'speed_kmh': 16.4, 'duration_s': 9, 'distance_m': 41}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 3, 285988), 'edge_id': '98041254_420456615', 'speed_kmh': 9.36, 'duration_s': 5, 'distance_m': 13}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 3, 448132), 'edge_id': '98041254_420522002', 'speed_kmh': 24.48, 'duration_s': 5, 'distance_m': 34}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 3, 605863), 'edge_id': '98041257_98041849', 'speed_kmh': 10.44, 'duration_s': 10, 'distance_m': 29}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 3, 748382), 'edge_id': '98041257_5710673974', 'speed_kmh': 15.84, 'duration_s': 5, 'distance_m': 22}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 3, 902710), 'edge_id': '98041257_5710673979', 'speed_kmh': 32.4, 'duration_s': 3, 'distance_m': 27}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 4, 58721), 'edge_id': '98041849_98041257', 'speed_kmh': 11.6, 'duration_s': 9, 'distance_m': 29}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 4, 198155), 'edge_id': '98041849_5718871870', 'speed_kmh': 12.6, 'duration_s': 6, 'distance_m': 21}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 4, 346325), 'edge_id': '98041849_733429120', 'speed_kmh': 11.14, 'duration_s': 21, 'distance_m': 65}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 4, 483930), 'edge_id': '98041851_98041254', 'speed_kmh': 22.44, 'duration_s': 168, 'distance_m': 1047}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 4, 623312), 'edge_id': '98041851_2084132002', 'speed_kmh': 34.2, 'duration_s': 4, 'distance_m': 38}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 4, 785275), 'edge_id': '98042270_309816682', 'speed_kmh': 18.39, 'duration_s': 121, 'distance_m': 618}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 4, 928146), 'edge_id': '98042270_6677300866', 'speed_kmh': 19.03, 'duration_s': 56, 'distance_m': 296}, {'timestamp': datetime.datetime(2025, 11, 27, 13, 11, 5, 78519), 'edge_id': '106078638_6 ...
#    💾 Đã lưu 983 dòng dữ liệu.
#    💤 Ngủ 130 giây chờ lượt tiếp theo...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 119
#     117 if sleep_time > 0:
#     118     print(f"   💤 Ngủ {int(sleep_time)} giây chờ lượt tiếp theo...")
# --> 119     time.sleep(sleep_time)
#     120 else:
#     121     print("   ⚠️ Quét full lâu hơn 5 phút, chạy tiếp ngay!")
#
# KeyboardInterrupt:
